# %%
print("hello world")
# Out:
# hello world

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9211, 0.2198, 0.1511],
#         [0.6916, 0.2709, 0.0639],
#         [0.4310, 0.2149, 0.4408],
#         [0.5036, 0.2603, 0.7491],
#         [0.3869, 0.9524, 0.3977]])
